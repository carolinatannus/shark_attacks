# %%
import os
os.listdir()
# Out:
# ['shark_analysis.ipynb',
#  'Untitled.ipynb',
#  'attacks.csv',
#  'README.md',
#  '.gitattributes',
#  '.ipynb_checkpoints',
#  '.git']

# %%
import numpy as np
import pandas as pd
pd.read_csv('attacks.csv', encoding='latin-1').tail(100)
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 25623         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25624         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25625         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25626         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25627         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25628         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25629         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25630         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25631         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25632         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25633         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# ...
